# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovitor12119-arch/global/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install -qq -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh
import subprocess
import time
import os

env = os.environ.copy()
env['HOME'] = '/root'
subprocess.Popen(['ollama', 'serve'], env=env,
                 stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
time.sleep(5)
print('Servidor Ollama iniciado!')
# !ollama pull llama3.2:1b
# !pip install ollama -q
print('Biblioteca ollama instalada!')
## 2. Importacoes
import ollama
print('Pronto!')
## 3. Configuracao e dados da missao
NOME_MISSAO = "Mission Control AI"
NOME_EQUIPE = """
Joao Vitor N F Giadans - RM 571608
Joao Victor Scheren - RM 568883
Julia Konishi - RM 569506
"""
MODELO_IA   = 'llama3.2:1b'

dados_missao = [
    [22, 95, 91, 98, 92],
    [26, 83, 75, 95, 86],
    [32, 67, 60, 92, 71],
    [37, 44, 35, 88, 52],
    [40, 25, 17, 76, 33],
    [35, 58, 30, 83, 48],
]

areas_monitoradas = [
    'Temperatura interna',
    'Comunicacao com a base',
    'Sistema de energia',
    'Suporte de oxigenio',
    'Estabilidade operacional',
]

print(f'Missao: {NOME_MISSAO} | Ciclos: {len(dados_missao)}')
## 4. Funcoes de analise
def analisar_temperatura(valor):
    if valor < 18:
        return 'ATENCAO', 'Temperatura baixa', 1
    elif valor <= 30:
        return 'NORMAL', 'Temperatura estavel', 0
    elif valor <= 35:
        return 'ATENCAO', 'Temperatura elevada', 1
    else:
        return 'CRITICO', 'Risco de superaquecimento', 2

def analisar_comunicacao(valor):
    if valor < 30:
        return 'CRITICO', 'Comunicacao com a base em nivel critico', 2
    elif valor < 60:
        return 'ATENCAO', 'Comunicacao instavel', 1
    else:
        return 'NORMAL', 'Comunicacao estavel', 0

def analisar_bateria(valor):
    if valor < 20:
        return 'CRITICO', 'Bateria em nivel critico', 2
    elif valor < 50:
        return 'ATENCAO', 'Bateria abaixo do recomendado', 1
    else:
        return 'NORMAL', 'Energia estavel', 0

def analisar_oxigenio(valor):
    if valor < 80:
        return 'CRITICO', 'Oxigenio em nivel critico', 2
    elif valor < 90:
        return 'ATENCAO', 'Oxigenio abaixo do ideal', 1
    else:
        return 'NORMAL', 'Oxigenio adequado', 0

def analisar_estabilidade(valor):
    if valor < 40:
        return 'CRITICO', 'Estabilidade operacional critica', 2
    elif valor < 70:
        return 'ATENCAO', 'Estabilidade operacional reduzida', 1
    else:
        return 'NORMAL', 'Estabilidade operacional adequada', 0

def classificar_ciclo(pontuacao):
    if pontuacao <= 2:
        return 'MISSAO ESTAVEL'
    elif pontuacao <= 5:
        return 'MISSAO EM ATENCAO'
    else:
        return 'MISSAO CRITICA'

def gerar_recomendacao(resultados):
    criticos = [area for area, (status, _, _) in resultados.items() if status == 'CRITICO']
    if not criticos:
        atencoes = [area for area, (status, _, _) in resultados.items() if status == 'ATENCAO']
        if not atencoes:
            return 'Manter operacao normal e continuar monitoramento.'
        return 'Monitorar sistemas em atencao e preparar plano de contingencia.'
    recomendacoes_map = {
        'Temperatura interna':      'Verificar controle termico da missao.',
        'Comunicacao com a base':   'Tentar restabelecer contato com a base.',
        'Sistema de energia':       'Ativar modo de economia de energia.',
        'Suporte de oxigenio':      'Acionar protocolo de suporte a vida.',
        'Estabilidade operacional': 'Reduzir operacoes nao essenciais.',
    }
    if len(criticos) >= 3:
        return 'Ativar modo de seguranca e priorizar suporte a vida, energia e comunicacao.'
    return ' | '.join(recomendacoes_map[area] for area in criticos if area in recomendacoes_map)

def analisar_tendencia(riscos):
    if riscos[-1] > riscos[0]:
        return 'A missao apresentou tendencia de piora.'
    elif riscos[-1] < riscos[0]:
        return 'A missao apresentou tendencia de melhora.'
    else:
        return 'A missao permaneceu estavel em relacao ao inicio.'

def identificar_area_mais_afetada(pontuacao_por_area):
    return max(pontuacao_por_area, key=pontuacao_por_area.get)

def analisar_ciclo(ciclo):
    temp, com, bat, oxi, est = ciclo
    return {
        'Temperatura interna':      analisar_temperatura(temp),
        'Comunicacao com a base':   analisar_comunicacao(com),
        'Sistema de energia':       analisar_bateria(bat),
        'Suporte de oxigenio':      analisar_oxigenio(oxi),
        'Estabilidade operacional': analisar_estabilidade(est),
    }

def calcular_risco_ciclo(resultados):
    return sum(pontos for _, (_, _, pontos) in resultados.items())

print('Funcoes de analise carregadas!')
## 5. Integracao com IA (Llama via Ollama)
SYSTEM_PROMPT = (
    'Voce eh ARIA, sistema de IA de controle da missao espacial. '
    'Analise os dados de telemetria e responda APENAS com: '
    '1) Nivel de risco: NORMAL, ATENCAO ou CRITICO. '
    '2) Principal problema (se houver). '
    '3) Uma acao recomendada. '
    'Maximo 3 linhas. Responda em portugues.'
)

def consultar_ia(numero_ciclo, ciclo, resultados, pontuacao, classificacao):
    temp, com, bat, oxi, est = ciclo
    criticos = [area for area, (status, _, _) in resultados.items() if status == 'CRITICO']
    atencoes = [area for area, (status, _, _) in resultados.items() if status == 'ATENCAO']
    prompt = (
        'CICLO ' + str(numero_ciclo) + ' | Classificacao: ' + classificacao + ' | Pontuacao: ' + str(pontuacao) + '\n'
        'Temperatura: ' + str(temp) + 'C | Comunicacao: ' + str(com) + '% | Bateria: ' + str(bat) + '%\n'
        'Oxigenio: ' + str(oxi) + '% | Estabilidade: ' + str(est) + '%\n'
        'Sistemas criticos: ' + str(criticos if criticos else 'nenhum') + '\n'
        'Sistemas em atencao: ' + str(atencoes if atencoes else 'nenhum') + '\n'
        'Forneca sua analise.'
    )
    resposta = ollama.chat(
        model=MODELO_IA,
        messages=[
            {'role': 'system', 'content': SYSTEM_PROMPT},
            {'role': 'user',   'content': prompt},
        ]
    )
    return resposta['message']['content']

print('Modulo de IA carregado!')
## 6. Funcoes de exibicao
def exibir_cabecalho():
    print('=' * 60)
    print('          MISSION CONTROL AI')
    print('=' * 60)
    print('  Missao : ' + NOME_MISSAO)
    print('  Equipe : ' + NOME_EQUIPE)
    print('  Ciclos : ' + str(len(dados_missao)))
    print('=' * 60)

def exibir_ciclo(numero, ciclo, resultados, pontuacao, classificacao, recomendacao, analise_ia):
    temp, com, bat, oxi, est = ciclo
    print('\nCICLO ' + str(numero))
    print('-' * 60)
    dados_exibicao = [
        ('Temperatura', str(temp) + ' C'),
        ('Comunicacao', str(com) + '%'),
        ('Bateria',     str(bat) + '%'),
        ('Oxigenio',    str(oxi) + '%'),
        ('Estabilidade',str(est) + '%'),
    ]
    for (label, valor), area in zip(dados_exibicao, areas_monitoradas):
        status, mensagem, _ = resultados[area]
        print('  ' + label.ljust(12) + ': ' + valor.ljust(6) + ' | ' + status.ljust(8) + ' | ' + mensagem)
    print('\n  Pontuacao de risco : ' + str(pontuacao))
    print('  Classificacao      : ' + classificacao)
    print('  Recomendacao       : ' + recomendacao)
    print('\n  Analise da IA (ARIA):')
    for linha in analise_ia.strip().split('\n'):
        print('    ' + linha)

def gerar_relatorio_final(riscos, pontuacao_por_area):
    print('\n' + '=' * 60)
    print('          RELATORIO FINAL DA MISSAO')
    print('=' * 60)
    print('  Missao : ' + NOME_MISSAO)
    print('  Equipe : ' + NOME_EQUIPE)
    print('  Ciclos analisados: ' + str(len(dados_missao)) + '\n')
    labels_medias = ['temperatura', 'comunicacao', 'bateria', 'oxigenio', 'estabilidade']
    unidades      = ['C', '%', '%', '%', '%']
    for i, (label, unidade) in enumerate(zip(labels_medias, unidades)):
        media = sum(c[i] for c in dados_missao) / len(dados_missao)
        print('  Media de ' + label.ljust(12) + ': ' + str(round(media, 2)) + unidade)
    ciclo_critico = riscos.index(max(riscos)) + 1
    risco_medio   = sum(riscos) / len(riscos)
    qtd_criticos  = sum(1 for r in riscos if r >= 6)
    tendencia     = analisar_tendencia(riscos)
    area_afetada  = identificar_area_mais_afetada(pontuacao_por_area)
    classif_final = classificar_ciclo(risco_medio)
    print('\n  Ciclo mais critico       : Ciclo ' + str(ciclo_critico))
    print('  Maior pontuacao de risco : ' + str(max(riscos)))
    print('  Risco medio da missao    : ' + str(round(risco_medio, 2)))
    print('  Ciclos criticos          : ' + str(qtd_criticos))
    print('\n  Tendencia da missao:')
    print('    ' + tendencia)
    print('\n  Pontuacao acumulada por area:')
    for area, pts in pontuacao_por_area.items():
        print('    ' + area + ': ' + str(pts) + ' pontos')
    print('\n  Area mais afetada:')
    print('    ' + area_afetada)
    print('\n  Classificacao final da missao:')
    print('    ' + classif_final)
    print('\n  Conclusao:')
    if risco_medio <= 2:
        conclusao = 'A missao transcorreu de forma estavel.'
    elif risco_medio <= 5:
        conclusao = 'A missao apresentou instabilidade relevante. Manter plano de contingencia ativo.'
    else:
        conclusao = 'A missao enfrentou situacoes criticas. Revisao completa necessaria.'
    print('    ' + conclusao)
    print('\n' + '=' * 60)

print('Funcoes de exibicao carregadas!')
## 7. Execucao principal
exibir_cabecalho()

riscos             = []
pontuacao_por_area = {area: 0 for area in areas_monitoradas}

for i, ciclo in enumerate(dados_missao):
    resultados    = analisar_ciclo(ciclo)
    pontuacao     = calcular_risco_ciclo(resultados)
    classificacao = classificar_ciclo(pontuacao)
    recomendacao  = gerar_recomendacao(resultados)
    analise_ia    = consultar_ia(i + 1, ciclo, resultados, pontuacao, classificacao)

    riscos.append(pontuacao)
    for area in areas_monitoradas:
        pontuacao_por_area[area] += resultados[area][2]

    exibir_ciclo(i + 1, ciclo, resultados, pontuacao, classificacao, recomendacao, analise_ia)

gerar_relatorio_final(riscos, pontuacao_por_area)
# Out:
# Selecting previously unselected package zstd.
# (Reading database ... 118242 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# Servidor Ollama iniciado!
#
# Biblioteca ollama instalada!
# Pronto!
# Missao: Mission Control AI | Ciclos: 6
# Funcoes de analise carregadas!
# Modulo de IA carregado!
# Funcoes de exibicao carregadas!
# ============================================================
#           MISSION CONTROL AI
# ============================================================
#   Missao : Mission Control AI
#   Equipe :
# Joao Vitor N F Giadans - RM 571608
# Joao Victor Scheren - RM 568883
# Julia Konishi - RM 569506
#
#   Ciclos : 6
# ============================================================
#
# CICLO 1
# ------------------------------------------------------------
#   Temperatura : 22 C   | NORMAL   | Temperatura estavel
#   Comunicacao : 95%    | NORMAL   | Comunicacao estavel
#   Bateria     : 91%    | NORMAL   | Energia estavel
#   Oxigenio    : 98%    | NORMAL   | Oxigenio adequado
#   Estabilidade: 92%    | NORMAL   | Estabilidade operacional adequada
#
#   Pontuacao de risco : 0
#   Classificacao      : MISSAO ESTAVEL
#   Recomendacao       : Manter operacao normal e continuar monitoramento.
#
#   Analise da IA (ARIA):
#     **Nível de Risco:** NORMAL
#
#     **Principal Problema:** A bateria está abaixo do nível recomendado.
#
#     **Ação Recomendada:** Realizar uma atualização imediata da bateria e garantir que ela esteja funcionando corretamente. Isso evitará qualquer problema potencial no futuro e mantém a missão estavel em operação normal.
#
# CICLO 2
# ------------------------------------------------------------
#   Temperatura : 26 C   | NORMAL   | Temperatura estavel
#   Comunicacao : 83%    | NORMAL   | Comunicacao estavel
#   Bateria     : 75%    | NORMAL   | Energia estavel
#   Oxigenio    : 95%    | NORMAL   | Oxigenio adequado
#   Estabilidade: 86%    | NORMAL   | Estabilidade operacional adequada
#
#   Pontuacao de risco : 0
#   Classificacao      : MISSAO ESTAVEL
#   Recomendacao       : Manter operacao normal e continuar monitoramento.
#
#   Analise da IA (ARIA):
#     **Nivel de Risco:** NORMAL
#
#     **Principal Problema:** Nenhum.
#
#     **Ação Recomendada:** Mantenha o sistema em operação normal, monitorando a temperatura, oxigenio e estabilidade. A missão está sem problemas críticos e não há necessidade de ajustes ou intervenções adicionais na atual hora.
#
# CICLO 3
# ------------------------------------------------------------
#   Temperatura : 32 C   | ATENCAO  | Temperatura elevada
#   Comunicacao : 67%    | NORMAL   | Comunicacao estavel
#   Bateria     : 60%    | NORMAL   | Energia estavel
#   Oxigenio    : 92%    | NORMAL   | Oxigenio adequado
#   Estabilidade: 71%    | NORMAL   | Estabilidade operacional adequada
#
#   Pontuacao de risco : 1
#   Classificacao      : MISSAO ESTAVEL
#   Recomendacao       : Monitorar sistemas em atencao e preparar plano de contingencia.
#
#   Analise da IA (ARIA):
#     **ANALISE DA MISSAO**
#
#     *   **Nivel de Risco:** CRITICO - A temperatura alta de 32C pode comprometer a segurança da missão e das equipamentos.
#     *   **Principal Problema:** Nenhuma mensagem crítica ou alerta, mas a baixa bateria (60%) pode ser um problema se a missão precisar permanecer por mais tempo.
#     *   **Ação Recomendada:** Reduzir a carga de bateria na estação de recarga para garantir a segurança da missão e evitar incidentes críticos.
#
# CICLO 4
# ------------------------------------------------------------
#   Temperatura : 37 C   | CRITICO  | Risco de superaquecimento
#   Comunicacao : 44%    | ATENCAO  | Comunicacao instavel
#   Bateria     : 35%    | ATENCAO  | Bateria abaixo do recomendado
#   Oxigenio    : 88%    | ATENCAO  | Oxigenio abaixo do ideal
#   Estabilidade: 52%    | ATENCAO  | Estabilidade operacional reduzida
#
#   Pontuacao de risco : 6
#   Classificacao      : MISSAO CRITICA
#   Recomendacao       : Verificar controle termico da missao.
#
#   Analise da IA (ARIA):
#     **Nível de Risco:** CRITICO
#
#     **Principal Problema:** Faltam dados importantes relacionados à capacidade de sustento dos sistemas criticos, especialmente em relação a oxigenio.
#
#     **Acao recomendada:** Realizar uma revisao da operacao para garantir que todos os sistemas estejam funcionando corretamente e estiverem em condições adequadas para realizar a missao. Isso inclui verificar se o sistema de oxigenio está funcionando corretamente, além de revisar outros sistemas criticos.
#
# CICLO 5
# ------------------------------------------------------------
#   Temperatura : 40 C   | CRITICO  | Risco de superaquecimento
#   Comunicacao : 25%    | CRITICO  | Comunicacao com a base em nivel critico
#   Bateria     : 17%    | CRITICO  | Bateria em nivel critico
#   Oxigenio    : 76%    | CRITICO  | Oxigenio em nivel critico
#   Estabilidade: 33%    | CRITICO  | Estabilidade operacional critica
#
#   Pontuacao de risco : 10
#   Classificacao      : MISSAO CRITICA
#   Recomendacao       : Ativar modo de seguranca e priorizar suporte a vida, energia e comunicacao.
#
#   Analise da IA (ARIA):
#     **Análise**
#
#     *   **Nivel de Risco:** CRITICO
#     *   **Principal problema:** Falta de oxigênio no sistema, o que pode afetar a combustível e a vida útil da missão.
#     *   **Ação recomendada:** Implementar uma substituição rápida do oxigênio antes de chegar à sua estação de reabastecimento.
#
#     **Conclusão**
#
#     O CICLO 5 apresenta preocupações significativas, especialmente em relação ao sistema de oxigênio. A falta de oxigênio pode ter consequências críticas para a missão e a segurança do pessoal envolvido. É fundamental tomar medidas imediatas para mitigar essa situação e evitar qualquer risco à vida humana.
#
# CICLO 6
# ------------------------------------------------------------
#   Temperatura : 35 C   | ATENCAO  | Temperatura elevada
#   Comunicacao : 58%    | ATENCAO  | Comunicacao instavel
#   Bateria     : 30%    | ATENCAO  | Bateria abaixo do recomendado
#   Oxigenio    : 83%    | ATENCAO  | Oxigenio abaixo do ideal
#   Estabilidade: 48%    | ATENCAO  | Estabilidade operacional reduzida
#
#   Pontuacao de risco : 5
#   Classificacao      : MISSAO EM ATENCAO
#   Recomendacao       : Monitorar sistemas em atencao e preparar plano de contingencia.
#
#   Analise da IA (ARIA):
#     **Nível de Risco:** CRITICO
#     **Problema Principal:** Sistemas em Atencao: ['Temperatura interna', 'Comunicacao com a base', 'Sistema de energia', 'Suporte de oxigenio', 'Estabilidade operacional']
#     **Ação Recomendada:** Reduzir a temperatura para 32C e aumentar a frequuencia da comunicação com a Base. Isso ajudará a manter a estabilidade operacional e evitar problemas críticos nos sistemas de energia e oxigênio.
#
#     Sistemas criticos estão funcionando corretamente, apesar do problema de temperatura. Aumentar a temperatura pode ter consequências negativas para a vida extraterrestre. Reduzir a temperatura é a melhor opção atuais.
#
# ============================================================
#           RELATORIO FINAL DA MISSAO
# ============================================================
#   Missao : Mission Control AI
#   Equipe :
# Joao Vitor N F Giadans - RM 571608
# Joao Victor Scheren - RM 568883
# Julia Konishi - RM 569506
#
#   Ciclos analisados: 6
#
#   Media de temperatura : 32.0C
#   Media de comunicacao : 62.0%
#   Media de bateria     : 51.33%
#   Media de oxigenio    : 88.67%
#   Media de estabilidade: 63.67%
#
#   Ciclo mais critico       : Ciclo 5
#   Maior pontuacao de risco : 10
#   Risco medio da missao    : 3.67
#   Ciclos criticos          : 2
#
#   Tendencia da missao:
#     A missao apresentou tendencia de piora.
#
#   Pontuacao acumulada por area:
#     Temperatura interna: 6 pontos
#     Comunicacao com a base: 4 pontos
#     Sistema de energia: 4 pontos
#     Suporte de oxigenio: 4 pontos
#     Estabilidade operacional: 4 pontos
#
#   Area mais afetada:
#     Temperatura interna
#
#   Classificacao final da missao:
#     MISSAO EM ATENCAO
#
#   Conclusao:
#     A missao apresentou instabilidade relevante. Manter plano de contingencia ativo.
#
# ============================================================
